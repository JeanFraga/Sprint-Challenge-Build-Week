# %%
import xgboost as xgb
import pandas as pd 
import numpy as np

# %%
df_numeric = pd.read_csv('train_numeric.csv')
df_numeric.head()
# Out:
#    Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  \
# 0   4     0.030    -0.034    -0.197    -0.179     0.118      0.116     -0.015
# 1   6       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2   7     0.088     0.086     0.003    -0.052     0.161      0.025     -0.015
# 3   9    -0.036    -0.064     0.294     0.330     0.074      0.161      0.022
# 4  11    -0.055    -0.086     0.294     0.330     0.118      0.025      0.030
#
#    L0_S0_F14  L0_S0_F16  ...  L3_S50_F4245  L3_S50_F4247  L3_S50_F4249  \
# 0     -0.032      0.020  ...           NaN           NaN           NaN
# 1        NaN        NaN  ...           NaN           NaN           NaN
# 2     -0.072     -0.225  ...           NaN           NaN           NaN
# 3      0.128     -0.026  ...           NaN           NaN           NaN
# 4      0.168     -0.169  ...           NaN           NaN           NaN
#
# ...

# %%
X_train = df_numeric.drop(['Response', 'Id'], axis=1)
y_train = df_numeric['Response']

# %%
model = xgb.XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
test_numeric = pd.read_csv('test_numeric.csv')

# y_test = test_numeric['Response']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-40b9f1192e80> in <module>()
#       1 test_numeric = pd.read_csv('test_numeric.csv')
# ----> 2 X_test = test_numeric.drop(['Response', 'Id'], axis=1)
#       3 y_test = test_numeric['Response']
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
test_numeric.head()
# Out:
#    Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  \
# 0   1       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 1   2       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2   3       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 3   5    -0.016    -0.026    -0.033    -0.016     0.205     -0.157        0.0
# 4   8       NaN       NaN       NaN       NaN       NaN        NaN        NaN
#
#    L0_S0_F14  L0_S0_F16  ...  L3_S50_F4243  L3_S50_F4245  L3_S50_F4247  \
# 0        NaN        NaN  ...           NaN           NaN           NaN
# 1        NaN        NaN  ...           NaN           NaN           NaN
# 2        NaN        NaN  ...           NaN           NaN           NaN
# 3      0.008      0.087  ...           NaN           NaN           NaN
# 4        NaN        NaN  ...           NaN           NaN           NaN
#
# ...

# %%
X_test = test_numeric.drop(['Id'], axis=1)

# %%
y_pred = model.predict(X_test)

# %%
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
predictions = [round(i) for i in y_pred]

# %%
ID = test_numeric[['Id', 'L0_S0_F0']]
ID = ID.rename(columns={'L0_S0_F0': 'Response'})

# %%
ID['Response'] = predictions

# %%
ID = ID.set_index('Id')

# %%
ID.to_csv('submission1.csv')
# !kaggle competitions submit -c bosch-production-line-performance -f submission1.csv -m "first attempt"
# Out:
# ...
# 100%|██████████████████████████████████████| 10.3M/10.3M [00:02<00:00, 4.41MB/s]
# Successfully submitted to Bosch Production Line Performance

# %%
ID[ID['Response'] == 1]
# Out:
#               Id  Response
# 2606        5180         1
# 4629        9311         1
# 4659        9367         1
# 5973       11979         1
# 8457       17028         1
# 8458       17029         1
# 10510      21125         1
# 10552      21211         1
# 13887      27784         1
# 13888      27785         1
# 14140      28331         1
# 14141      28332         1
# 15678      31337         1
# 20171      40279         1
# 23337      46591         1
# 30288      60517         1
# 34739      69287         1
# 36376      72550         1
# 36506      72842         1
# 36507      72843         1
# 36508      72844         1
# 41568      83039         1
# 41569      83040         1
# 43407      86763         1
# 43906      87765         1
# 45444      90926         1
# 45662      91342         1
# 49934      99731         1
# 49935      99732         1
# 59030     117947         1
# ...          ...       ...
# 1075105  2149928         1
# 1075811  2151307         1
# ...

# %%
ID.shape
# Out:
# (1130696, 2)

# %%
submision1 = pd.read_csv('sample_submission.csv')
submision1.head()
# Out:
#    Id  Response
# 0   1         0
# 1   2         0
# 2   3         0
# 3   5         0
# 4   8         0

# %%
submision1['Response'] = ID['Response']

# %%
submision1.shape
# Out:
# (1183748, 2)

# %%
submision1.head()
# Out:
#    Id  Response
# 0   1       0.0
# 1   2       0.0
# 2   3       0.0
# 3   5       0.0
# 4   8       0.0

# %%
submision1 = submision1.fillna(0)

# %%
submision1 = submision1.astype(int)

# %%
submision1 = submision1.set_index('Id')

# %%
submision1.to_csv('submission1.csv')
# !kaggle competitions submit -c bosch-production-line-performance -f submission1.csv -m "first attempt"
# Out:
# ...
# 100%|██████████████████████████████████████| 10.8M/10.8M [00:03<00:00, 3.22MB/s]
# Successfully submitted to Bosch Production Line Performance

# %%
# df_date = pd.read_csv('train_date.csv', nrows=50000)
# df_date.head()

# %%
# df_date = pd.read_csv('train_categorical.csv', nrows=50000)
# df_date.head()

# %%
# train = pd.merge(
#     pd.read_csv('train_numeric.csv', nrows=500),
#     pd.read_csv('train_date.csv', nrows=500),
#     pd.read_csv('train_categorical.csv', nrows=500),
#     # on='Id',
#     left_on='Id'
# )
# train.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-01d4b8539ddb> in <module>
# ----> 1 train = pd.merge(
#       2     pd.read_csv('train_numeric.csv', nrows=500),
#       3     pd.read_csv('train_date.csv', nrows=500),
#       4     pd.read_csv('train_categorical.csv', nrows=500),
#       5     # on='Id',
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
